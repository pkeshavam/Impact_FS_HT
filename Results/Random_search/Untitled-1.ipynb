# %%
# %run data_processing.py
# Out:
# Data preprocessing complete!

# %%
# %run model_training2.py
# Out:
# Training Support Vector Machine without hyperparameter tuning...
# Support Vector Machine training completed in 0.03 seconds.
#
# Training K-Nearest Neighbors without hyperparameter tuning...
# K-Nearest Neighbors training completed in 0.00 seconds.
#
# Training XGBoost without hyperparameter tuning...
# XGBoost training completed in 0.05 seconds.
#
# Model saved: Models/no_tuning/support_vector_machine_model.pkl
# Model saved: Models/no_tuning/k-nearest_neighbors_model.pkl
# Model saved: Models/no_tuning/xgboost_model.pkl
# Tuning and training Support Vector Machine...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /opt/anaconda3/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [16:14:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Support Vector Machine training with tuning completed in 2.87 seconds.
# ...

# %%
# %run evaluation.py
# Out:
# Evaluating models in directory: Models/no_tuning...
# Evaluating Support Vector Machine (Not Tuned)...
# Confusion matrix saved to Plots/no_tuning/support_vector_machine_not_tuned_confusion_matrix.png.
# ROC curve saved to Plots/no_tuning/support_vector_machine_not_tuned_roc_curve.png.
# Evaluating K-Nearest Neighbors (Not Tuned)...
# Confusion matrix saved to Plots/no_tuning/k-nearest_neighbors_not_tuned_confusion_matrix.png.
# ROC curve saved to Plots/no_tuning/k-nearest_neighbors_not_tuned_roc_curve.png.
# Evaluating Xgboost (Not Tuned)...
# Confusion matrix saved to Plots/no_tuning/xgboost_not_tuned_confusion_matrix.png.
# ROC curve saved to Plots/no_tuning/xgboost_not_tuned_roc_curve.png.
# Metrics saved to Metrics/evaluation_no_tuning.csv.
# Evaluating models in directory: Models/with_tuning...
# Evaluating Support Vector Machine (Tuned)...
# Confusion matrix saved to Plots/with_tuning/support_vector_machine_tuned_confusion_matrix.png.
# ...

# %%
# %run main_11_binary.py
# Out:
# Loading and preprocessing data...
# Processing finished.
# Number of training examples: 117678
# Available models: ['LSVC', 'LR', 'KNN', 'RF']
#
# Processing model: LSVC
# Training LSVC without hyperparameter tuning...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Downloads/January_2025/ML_1_midterm/main_11_binary.py:205
#     202         print(f"Training and evaluation of {selected_model} completed.")
#     204 if __name__ == "__main__":
# --> 205     main()
#
# File ~/Downloads/January_2025/ML_1_midterm/main_11_binary.py:111, in main()
#     107     trained_model, train_times, best_hyperparameters = train_with_tuning(
#     108         {selected_model: models_params[selected_model]}, X_train, y_train
#     109     )
#     110 else:
# --> 111     trained_model, train_times = train_without_tuning(
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')    #use this command  1 for colab
# Navigate to the repository
repo_path = '/content/drive/MyDrive/machine_learning_Multiclass_classification'
import os
os.chdir(repo_path)    #use this command 2 for colab
# !python main.py   #command 3 to run python packages or scripts directly
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading and preprocessing data...
# Processing finished.
# Number of training examples: 1658964
# Available models: ['Support Vector Machine', 'K-Nearest Neighbors', 'Random Forest', 'LR', 'XGBoost']
# Enter the model name to train and test: XGBoost
# Do you want to run with hyperparameter tuning? (yes/no): yes
# Training XGBoost with hyperparameter tuning...
# Training with tuning starting.
# Tuning and training XGBoost...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# XGBoost training with tuning completed in 59.96 seconds.
# Best parameters for XGBoost: {'max_depth': 3, 'n_estimators': 100}
#
# 11_binary
# Model saved: Models/with_tuning/xgboost_model_11_binary.pkl
# save_train_times=True
# training_times=None
# best hyperparameters: {'XGBoost': {'max_depth': 3, 'n_estimators': 100}}
# ...
